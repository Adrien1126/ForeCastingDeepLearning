# %%
# Ajouter le dossier `src` au chemin de recherche Python
import sys
import os
sys.path.append(os.path.abspath('../src'))
from data_processing.preprocessing import *
from utils.plotting import *

# %%
# Liste des symboles des principales banques européennes
european_banks = [
    'BNP.PA',   # BNP Paribas
    'GLE.PA',   # Société Générale 
    'ACA.PA',   # Crédit Agricole 
    'HSBA.L',   # HSBC (UK)
    'BARC.L',   # Barclays (UK)
    'DBK.DE',   # Deutsche Bank (Germany)
    'UBSG.SW',  # UBS Group (Switzerland)
    'INGA.AS',  # ING Group (Netherlands)
    'ISP.MI',   # Intesa Sanpaolo (Italy)
    'SAN.MC',   # Banco Santander (Spain)
    'BBVA.MC'   # BBVA (Spain)
]

# à partir de 2013
start_date = '2013-01-01'
end_date = '2024-11-07'

data = prepare_stock_data(european_banks, start_date, end_date)
# Out:
# Téléchargement des données pour BNP.PA...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour GLE.PA...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour ACA.PA...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour HSBA.L...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour BARC.L...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour DBK.DE...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour UBSG.SW...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour INGA.AS...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour ISP.MI...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour SAN.MC...
# [*********************100%%**********************]  1 of 1 completed
# Téléchargement des données pour BBVA.MC...
# [*********************100%%**********************]  1 of 1 completed
# Nombre de valeurs manquantes au début : 0
# Nombre total de valeurs manquantes après traitement: 0

# %%
# Extraire la série des prix de clôture ajustés pour BNP Paribas
bnp_close_price = data[('BNP.PA', 'Adj Close')]

# Appeler la fonction pour tracer les prix
plot_close_price(bnp_close_price, "BNP Paribas")

# %%
# Appel de la fonction avec vos données
data = add_log_returns_and_volume(data, european_banks)
# Out:
# Calcul des log returns et du volume pour BNP.PA...
# Calcul des log returns et du volume pour GLE.PA...
# Calcul des log returns et du volume pour ACA.PA...
# Calcul des log returns et du volume pour HSBA.L...
# Calcul des log returns et du volume pour BARC.L...
# Calcul des log returns et du volume pour DBK.DE...
# Calcul des log returns et du volume pour UBSG.SW...
# Calcul des log returns et du volume pour INGA.AS...
# Calcul des log returns et du volume pour ISP.MI...
# Calcul des log returns et du volume pour SAN.MC...
# Calcul des log returns et du volume pour BBVA.MC...
# Aperçu des données avec log returns et colonnes conservées :
#                BNP.PA                                                         \
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2013-01-03  44.240002  44.544998  44.014999  44.459999  22.753109  1719620.0
# 2013-01-04  44.360001  44.720001  43.955002  44.384998  22.714727  1969483.0
# 2013-01-07  45.250000  46.064999  45.119999  45.209999  23.136936  4186011.0
# 2013-01-08  45.154999  46.555000  45.064999  45.695000  23.385139  4068024.0
# 2013-01-09  45.915001  46.334999  44.830002  45.639999  23.356995  4651803.0
#
#                GLE.PA                                   ...             \
#                  Open       High        Low      Close  ... Log Return
# Date                                                    ...
# 2013-01-03  29.799999  29.850000  29.400000  29.575001  ...  -0.009255
# 2013-01-04  29.575001  29.620001  29.110001  29.330000  ...  -0.008319
# 2013-01-07  30.299999  30.434999  29.905001  30.129999  ...   0.026911
# 2013-01-08  30.190001  31.355000  30.000000  31.084999  ...   0.031204
# 2013-01-09  31.389999  32.185001  31.235001  32.150002  ...   0.033687
#
#                ACA.PA     HSBA.L     BARC.L     DBK.DE    UBSG.SW    INGA.AS  \
#            Log Return Log Return Log Return Log Return Log Return Log Return
# Date
# 2013-01-03  -0.000315  -0.004819   0.001451   0.010918   0.000000   0.002743
# 2013-01-04   0.000787   0.007668   0.002533   0.007357  -0.008793   0.012250
# 2013-01-07   0.034804  -0.002099   0.037245   0.027919   0.018843   0.026038
# 2013-01-08   0.008025  -0.010563   0.000000   0.012362   0.005982  -0.015675
# 2013-01-09   0.045258   0.016101   0.025949   0.013165   0.040265   0.024729
#
#                ISP.MI     SAN.MC    BBVA.MC
#            Log Return Log Return Log Return
# Date
# 2013-01-03  -0.002184  -0.003482  -0.005781
# 2013-01-04   0.007262   0.003640   0.010026
# 2013-01-07   0.015794  -0.001264   0.011953
# 2013-01-08  -0.000713   0.002843   0.006058
# 2013-01-09   0.024641   0.009575   0.032872
#
# [5 rows x 77 columns]
# Taille du DataFrame amélioré : (3042, 77)

# %%
# Extraire la série des log returns pour BNP Paribas
bnp_log_return = data[('BNP.PA', 'Log Return')]

# Appeler la fonction pour tracer les log returns
plot_log_return(bnp_log_return, "BNP Paribas")
